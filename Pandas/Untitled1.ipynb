# %%
import pandas as pd
import numpy as np
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
var = pd.DataFrame(exam_data,index=labels)
#var.loc[['b','d','f','g'],['score','qualify']]
#var[(var['score']>15) & (var['attempts']<2)]
#var.loc['d',"score"] = 11.5
#var[var['score'].between(15,20)]
print(var['attempts'].sum())
print(var['score'].mean())
#var.loc['k'] = ["Suresh", 15.5, 1, "yes"]
#var.drop('k')
print(var.sort_values(by=["name","score"] ,ascending=[False,True]))
#var.replace(['yes','no'],['True','False'])
var.loc['d',"name"]="Suresh"
var
# Out:
# 19
# 13.5625
#         name  score  attempts qualify
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# b       Dima    9.0         3      no
# a  Anastasia   12.5         1     yes
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d     Suresh    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
import pandas as pd
#s = {"name":["harsh","manvik"], "course":"data science","fee":3000}
s=[1,2,3,4]
index = [25,6,7,9]
s1 =  pd.Series(s,index=index)
s1
# Out:
# 25    1
# 6     2
# 7     3
# 9     4
# dtype: int64

# %%
d = {"name":["Pedestal","harsh","naman"],
     "fee":[3000,2000,1000]}
ds = pd.DataFrame(d)
ds
# Out:
#        name   fee
# 0  Pedestal  3000
# 1     harsh  2000
# 2     naman  1000

# %%
cs1 = pd.read_csv("tips.csv")
#print(cs1.to_string())
print(cs1.head(50))
#pd.options.display.max_rows=100 when our system does not show all file then we define the max_display
print(cs1.tail())
print(sc1.info())
# Out:
#     total_bill   tip  gender smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
import pandas as pd
cs1 = pd.read_csv("tips.csv")
print(cs1.shape)
cs2 = cs1.dropna()
print(cs2.shape)
print(cs2.to_string())
# Out:
# (244, 7)
# (244, 7)
#      total_bill    tip  gender smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...
