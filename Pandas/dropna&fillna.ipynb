# %% [markdown]
# dropna & fillna

# %%
import pandas as pd
var = pd.read_csv("C:\\Users\\HP Pavilion\\OneDrive\\Desktop\\Portfolio\\Python\\Pandas\\SalesReport2.csv")
var
# Out:
#               Product Customer     Qtr 1     Qtr 2       Qtr 3     Qtr 4
# 0        Alice Mutton    ANTON     $-     $702.00        $-        $-
# 1        Alice Mutton    BERGS  $312.00      $-          $-        $-
# 2        Alice Mutton    BOLID     $-          NaN       $-          NaN
# 3        Alice Mutton    BOTTM       NaN     $-          $-        $-
# 4        Alice Mutton    ERNSH       NaN     $-          $-          NaN
# 5        Alice Mutton    GODOS     $-     $280.80        $-        $-
# 6        Alice Mutton    HUNGC   $62.40      $-          $-        $-
# 7        Alice Mutton    PICCO     $-          NaN    $936.00      $-
# 8        Alice Mutton    RATTC     $-     $592.80        $-        $-
# 9        Alice Mutton    REGGC     $-        $-          $-     $741.00
# 10       Alice Mutton    SAVEA     $-        $-            NaN  $789.75
# 11       Alice Mutton    SEVES       NaN  $877.50        $-        $-
# ...

# %%
var.dropna()
# Out:
#               Product Customer     Qtr 1     Qtr 2       Qtr 3     Qtr 4
# 0        Alice Mutton    ANTON     $-     $702.00        $-        $-
# 1        Alice Mutton    BERGS  $312.00      $-          $-        $-
# 5        Alice Mutton    GODOS     $-     $280.80        $-        $-
# 6        Alice Mutton    HUNGC   $62.40      $-          $-        $-
# 8        Alice Mutton    RATTC     $-     $592.80        $-        $-
# 9        Alice Mutton    REGGC     $-        $-          $-     $741.00
# 12       Alice Mutton    WHITC     $-        $-          $-     $780.00
# 13      Aniseed Syrup    ALFKI     $-        $-          $-      $60.00
# 15      Aniseed Syrup    ERNSH     $-        $-          $-     $180.00
# 16      Aniseed Syrup    LINOD  $544.00      $-          $-        $-
# 17      Aniseed Syrup    QUICK     $-     $600.00        $-        $-
# 19   Boston Crab Meat    ANTON     $-     $165.60        $-        $-
# ...

# %%
#var.dropna(axis=1) # 1 for column and 0 for row

# %%
#var.dropna(how="all")    #here when we use any it will remove all the NA but all will remove only which have all row index NA

# %%
var.dropna(subset=["Qtr 2"])
# Out:
#               Product Customer     Qtr 1     Qtr 2       Qtr 3     Qtr 4
# 0        Alice Mutton    ANTON     $-     $702.00        $-        $-
# 1        Alice Mutton    BERGS  $312.00      $-          $-        $-
# 3        Alice Mutton    BOTTM       NaN     $-          $-        $-
# 4        Alice Mutton    ERNSH       NaN     $-          $-          NaN
# 5        Alice Mutton    GODOS     $-     $280.80        $-        $-
# 6        Alice Mutton    HUNGC   $62.40      $-          $-        $-
# 8        Alice Mutton    RATTC     $-     $592.80        $-        $-
# 9        Alice Mutton    REGGC     $-        $-          $-     $741.00
# 10       Alice Mutton    SAVEA     $-        $-            NaN  $789.75
# 11       Alice Mutton    SEVES       NaN  $877.50        $-        $-
# 12       Alice Mutton    WHITC     $-        $-          $-     $780.00
# 13      Aniseed Syrup    ALFKI     $-        $-          $-      $60.00
# ...

# %%
var.dropna(thresh= 3)
# Out:
#               Product Customer     Qtr 1     Qtr 2       Qtr 3     Qtr 4
# 0        Alice Mutton    ANTON     $-     $702.00        $-        $-
# 1        Alice Mutton    BERGS  $312.00      $-          $-        $-
# 2        Alice Mutton    BOLID     $-          NaN       $-          NaN
# 3        Alice Mutton    BOTTM       NaN     $-          $-        $-
# 4        Alice Mutton    ERNSH       NaN     $-          $-          NaN
# 5        Alice Mutton    GODOS     $-     $280.80        $-        $-
# 6        Alice Mutton    HUNGC   $62.40      $-          $-        $-
# 7        Alice Mutton    PICCO     $-          NaN    $936.00      $-
# 8        Alice Mutton    RATTC     $-     $592.80        $-        $-
# 9        Alice Mutton    REGGC     $-        $-          $-     $741.00
# 10       Alice Mutton    SAVEA     $-        $-            NaN  $789.75
# 11       Alice Mutton    SEVES       NaN  $877.50        $-        $-
# ...

# %%
#var.fillna({"Product":"Python","Customer":"Manav","Qtr 1":"$10","Qtr 2":"$20"})

# %%
#var.fillna(method="ffill") var.fillna(method="bfill") in this we will fill tha nan with the backbward or forward index value

# %%
#var.fillna(method="bfill",axis=1)

# %%
# var.fillna(12,inplace=True)
# var

# %%
var.fillna("python",limit=2)
# Out:
#               Product Customer     Qtr 1     Qtr 2       Qtr 3     Qtr 4
# 0        Alice Mutton    ANTON     $-     $702.00        $-        $-
# 1        Alice Mutton    BERGS  $312.00      $-          $-        $-
# 2        Alice Mutton    BOLID     $-       python       $-       python
# 3        Alice Mutton    BOTTM    python     $-          $-        $-
# 4        Alice Mutton    ERNSH    python     $-          $-       python
# 5        Alice Mutton    GODOS     $-     $280.80        $-        $-
# 6        Alice Mutton    HUNGC   $62.40      $-          $-        $-
# 7        Alice Mutton    PICCO     $-       python    $936.00      $-
# 8        Alice Mutton    RATTC     $-     $592.80        $-        $-
# 9        Alice Mutton    REGGC     $-        $-          $-     $741.00
# 10       Alice Mutton    SAVEA     $-        $-         python  $789.75
# 11       Alice Mutton    SEVES       NaN  $877.50        $-        $-
# ...
