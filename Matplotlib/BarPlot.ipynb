# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [5,10,15,20]
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Bar Plot

# %%
language = ["python","C", "C++","Java"]
popular = [85,70,65,82]
z = [20,30,40,50]

c = ["gold","royalblue","navy","teal"]

plt.xlabel("Languages",fontsize=15)
plt.ylabel("Popular Score",fontsize=10)
plt.title("Matplotlib bar",fontsize=15)

# plt.bar(language,popular, color=c,width=0.4,align="edge",edgecolor="aqua",linewidth=4,linestyle=":",alpha=0.6)

plt.bar(language,popular, color="r",width=0.4,label="popularity")
plt.bar(language,z, color="gold",width=0.4,label="popularity1")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

language = ["python","C", "C++","Java"]
popular = [85,70,65,82]
z = [20,30,40,50]

width=0.2

p =np.arange(len(language))
p1 = [j+width for j in p]

plt.xlabel("Languages",fontsize=15)
plt.ylabel("Popular Score",fontsize=10)
plt.title("Matplotlib bar",fontsize=15)

plt.barh(p,popular,width ,color="r",label="popularity")
plt.barh(p1,z,width, color="gold",label="popularity1")

#to show the name of language
plt.xticks(p+width/2,language,rotation=90)
plt.legend()
plt.show()

# %%
language = ["python","C", "C++","Java"]
popular = [85,70,65,82]
z = [20,30,40,50]

c = ["gold","royalblue","navy","teal"]

plt.xlabel("Languages",fontsize=15)
plt.ylabel("Popular Score",fontsize=10)
plt.title("Matplotlib bar",fontsize=15)

# plt.bar(language,popular, color=c,width=0.4,align="edge",edgecolor="aqua",linewidth=4,linestyle=":",alpha=0.6)

plt.barh(language,popular, color="r",label="popularity")
plt.bar(language,z, color="gold",label="popularity1")

plt.legend()
plt.show()
